# %%
from pyalgotrade import plotter
from pyalgotrade.barfeed import quandlfeed
from pyalgotrade.stratanalyzer import returns
import sma_crossover

# %%
# Load the bar feed from the CSV file
feed = quandlfeed.Feed()
feed.addBarsFromCSV("orcl", "WIKI-ORCL.csv")

# %%
# Evaluate the strategy with the feed's bars.
myStrategy = sma_crossover.SMACrossOver(feed, "orcl", 20)

# Attach a returns analyzers to the strategy.
returnsAnalyzer = returns.Returns()
myStrategy.attachAnalyzer(returnsAnalyzer)

# %%
# Attach the plotter to the strategy.
plt = plotter.StrategyPlotter(myStrategy)
# Include the SMA in the instrument's subplot to get it displayed along with the closing prices.
plt.getInstrumentSubplot("orcl").addDataSeries("SMA", myStrategy.getSMA())
# Plot the simple returns on each bar.
plt.getOrCreateSubplot("returns").addDataSeries("Simple returns", returnsAnalyzer.getReturns())

# %%
# Run the strategy.
myStrategy.run()
myStrategy.info("Final portfolio value: $%.2f" % myStrategy.getResult())
# Out:
# 1991-02-06 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [75] for 1701855 share/s
# 1991-02-07 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [75] for 1701855 share/s
# 1991-02-11 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [75] for 1082485 share/s
# 1991-02-12 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [75] for 1082485 share/s
# 1991-02-13 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [75] for 1082485 share/s
# 1991-02-14 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [75] for 1082485 share/s
# 1991-02-15 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [75] for 1082485 share/s
# 1991-02-19 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [75] for 1082485 share/s
# 1991-02-20 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [75] for 1082485 share/s
# 1992-01-09 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 1508378 share/s
# 1992-01-14 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-15 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-16 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-17 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-20 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-21 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-22 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-23 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-24 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-27 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-28 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-29 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-30 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-01-31 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-03 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-04 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-05 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-06 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-07 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-10 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-11 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-12 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-13 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-14 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-18 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-19 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-20 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-21 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-24 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-25 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-26 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-27 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 1992-02-28 00:00:00 broker.backtesting [DEBUG] Not enough cash to fill orcl order [89] for 562280 share/s
# 2019-05-02 11:11:57,809 strategy [INFO] Final portfolio value: $3123884.13

# %%
# Plot the strategy.
plt.plot()
